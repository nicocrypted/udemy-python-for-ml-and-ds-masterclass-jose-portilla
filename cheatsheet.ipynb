# %%
pwd # print out the current working directory
# Out:
# '/Users/su/projects/github/udemy-python-for-ml-and-ds-masterclass-jose-portilla'

# %%
import numpy as np
import pandas as pd

# %%
# Apply method: Build a custom function and apply it to a Pandas Series
# Example:
def last_four(num):
    '''Grab the last for digits of the num value.'''
    return str(num)[-4:]
df = 'Some Pandas dataframe'
df['CC Number'].apply(last_four)

# Another example with a more complex function:
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'
df['yelp'] = df['total_bill'].apply(yelp)

#Apply method using lambda function:
df['total_bill'].apply(lambda num: num*2)

#Apply function on multiple columns:
def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return 'Generous'
    else:
        return 'Other'

df['Quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis = 1)

# Use vectorize to speed up computations
df['Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
# Track time running of code:
import timeit
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv)
def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return 'Generous'
    else:
        return 'Other'
'''

# Code snippet whose execution time is to be measured
stmt_one = '''
df['Quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis = 1)
'''

stmt_two = '''
df['Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, stmt = stmt_one , number = 1000)

# %%
timeit.timeit(setup = setup, stmt = stmt_two, number = 1000)

# %%
#Replace values in a dataframe:
df['sex'].replace(['Female' 'Male'], [0, 1])

#Or even more cleaner method:
mymap = {'Female': 0, 'Male': 1}
df['sex'].map(mymap)

# %%
#Subselect based on a range of values inside a column:
df[df['total_bill'].between(10, 20, inclusive=True)]

# %% [markdown]
# #Pick the n largest values of a dataframe:
# df.nlargest(5, 'tip')

# %%
# Fill NaN values with the mean of a column:
df['pre_movie_score'].fillna(df['pre_movie_score'].mean())

# Or apply it to the entire df column-wise:
df.fillna(df.mean())

# %%
# Fill NaN values with interpolated values:
airline_tix = {'first': 100, 'business' : np.nan, 'economy-plus' : 50, 'economy' : 30}
ser = pd.Series(airline_tix)
ser.interpolate()
# Out:
# first           100.0
# business         75.0
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %%
# Join Dataframes on index and columns at once:
pd.merge(df1, df2, left_index = True, right_on = 'name')

# Merge dataframes on different column names:
pd.merge(df1, df2, left_on = 'reg_name', right_on = 'name')
