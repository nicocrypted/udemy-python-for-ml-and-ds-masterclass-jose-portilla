# %%
print("My name is {}, my number is {}".format('Nico', '10'))
# Out:
# My name is Nico, my number is 10

# %%
print("First: {x} Second: {y}".format(x='XXX', y='yyy'))
# Out:
# First: XXX Second: yyy

# %%
t = (1, 2, 3) # Tuple: Values cannot be changed by assignment.
# Out:
# [1, 2, 3]

# %%
x = [1, 2, 3, 4, 5]
[num**2 for num in x] # List comprehension.
# Out:
# [1, 4, 9, 16, 25]

# %%
lambda var: var*2 # Anonymous function
# Out:
# <function __main__.<lambda>(var)>

# %%
# Sting operations
st = 'Hello my name is Sam'

print(st.lower())
print(st.upper())
print(st.split())

tweet = 'Hello #sports'
print(tweet.split('#')[-1])
# Out:
# hello my name is sam
# HELLO MY NAME IS SAM
# ['Hello', 'my', 'name', 'is', 'Sam']
# sports
